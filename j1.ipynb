# %%
import pandas as pd

df = pd.read_json("/content/GenMedGPT-5k.json")
df.head()
# Out:
#                                          instruction  \
# 0  If you are a doctor, please answer the medical...
# 1  If you are a doctor, please answer the medical...
# 2  If you are a doctor, please answer the medical...
# 3  If you are a doctor, please answer the medical...
# 4  If you are a doctor, please answer the medical...
#
#                                                input  \
# 0  Doctor, I have been experiencing sudden and fr...
# 1  Doctor, I have been experiencing a hoarse voic...
# 2  Hi, Doctor. I think I might have Turner syndro...
# 3  Doctor, I've been experiencing a condition cal...
# 4  Doctor, I think I've been poisoned. I drank so...
#
#                                               output
# 0  Well, based on what you're telling me, it soun...
# 1  It's possible that you have a vocal cord polyp...
# 2  Okay, in that case, you will need to undergo a...
# 3  You will need to undergo a complete physical s...
# 4  I'm sorry to hear that. We need to run a few t...

# %%
clean_instruction='if you are a doctor please answer the medical questions based on the patients description'
df=df.drop('instruction',axis=1)

# %%
import pandas as pd
import re
import string

def clean_text(text):
    text = str(text)
    text = re.sub(r"[^\x00-\x7F]+", " ", text)
    text = re.sub(r"http\S+|www.\S+", " ", text)
    text = re.sub(r"<.*?>", " ", text)
    text = text.translate(str.maketrans("", "", string.punctuation))
    text = re.sub(r"\d+", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    text = text.lower()
    return text



df["input"] = df["input"].apply(clean_text)
df["output"] = df["output"].apply(clean_text)

df
# Out:
#                                                   input  \
# 0     doctor i have been experiencing sudden and fre...
# 1     doctor i have been experiencing a hoarse voice...
# 2        hi doctor i think i might have turner syndrome
# 3     doctor ive been experiencing a condition calle...
# 4     doctor i think ive been poisoned i drank some ...
# ...                                                 ...
# 5447  doctor i have an open wound in my nose and i a...
# 5448  doctor i have an open wound in my nose and my ...
# 5449  doctor i have an open wound on my nose and im ...
# 5450  doctor i have a sore in my nose and i keep get...
# 5451  doctor i have an open wound on my nose and i a...
#
#                                                  output
# 0     well based on what youre telling me it sounds ...
# 1     its possible that you have a vocal cord polyp ...
# 2     okay in that case you will need to undergo a c...
# 3     you will need to undergo a complete physical s...
# 4     im sorry to hear that we need to run a few tes...
# ...                                                 ...
# 5447  based on your symptoms you may have a complica...
# 5448  based on your symptoms you may have a staph in...
# 5449  hot flashes are a common symptom of menopause ...
# 5450  it sounds like you have an open wound in your ...
# 5451  it seems like you have an infection in your no...
#
# [5452 rows x 2 columns]

# %%
df.to_csv("clean_data.csv", index=False, encoding="utf-8")
